# %%
import requests

# %% [markdown]
# html_text = requests.get('Link').text

# %% [markdown]
# let us consider the link of a job website such as timesjobs.com

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Data+Analyst&txtLocation=India&cboWorkExp1=0').text

# %%
print(html_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <head>
#
#
# 	<link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet">
# 		<link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#        <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#       	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js"></script>
#       	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js"></script>
# 		<!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.7"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js"></script>
#
#
#         <link rel="canonical" href="https://www.timesjobs.com/candidate/job-search.html"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 						<link rel="next" href="https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Data+Analyst&txtLocation=India&cboWorkExp1=0/&sequence=2&startPage=1"/>
#
#
#
#
#
#
#
#
#
# 				<title>data analyst Jobs in India  with Entry Level experience - TimesJobs</title>
#
#
#
#
# 			<meta name="description" content="Jobs in data analyst in India  with Entry Level experience. Search and apply jobs online at Timesjobs.com"/>
#
#
# 		<!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#         <script>
#           //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#         </script>
#
#
#                               <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="C4P83-FLD8C-N9VTA-RP2SP-ZADRK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"C4P83-FLD8C-N9VTA-RP2SP-ZADRK";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="nlgy2qyxhjo3ayyyopfa-f-6a5bc68da-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"32","ak.cp":"1277284","ak.ai":parseInt("765140",10),"ak.ol":"0","ak.cr":96,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"2094386b","ak.r":35512,"ak.a2":n,"ak.m":"j","ak.n":"essl","ak.bpcip":"106.205.141.0","ak.cport":61881,"ak.gh":"23.58.93.172","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1662546890","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"6","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
#   	<body>
#   		<div id="site">
#
#
# 				<!-- Header Starts -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# 	<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4"
# 		height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#
#
#
#
# <script type="text/javascript" src="https://wchat.freshchat.com/js/widget.js"></script>
# <script>
# window.fcWidget.init({
# token: "d7130618-a917-400b-804c-bdf44d8d178b",
# host: "https://wchat.freshchat.com",
# config: {
# headerProperty: {
# hideChatButton: true
# }
#         }
# });
#
# </script>
#
#
#
#
#
# <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
#
# <script type="text/javascript" src='https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js' ></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<div id="fb_connect_suggest" style="display: none;" class="msg notify">
# 		Dear Jobseeker, Find millions of jobs on single click.
# 		<span id="fb_auto_connect"><a href="javascript:fconnect_auto();"><img src='https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png' alt='fconnect'></a></span>
# 		<span class="big-cls cls-icn" title="Click to Hide" onclick="javascript:ack_fbconnect_cancel();"><i class="material-icons">close</i></span>
# 		<span id="fb_connect_status"></span>
# 		</div>
# 		<div id="fb_connect_success" style="display: none;" class="msg success">
# 			Congratulations! You have been logged in via Facebook
# 		</div>
#
#
#
#
# <header class="main-header">
# <div class="top-header">
# 	<div class="ubility-wrap clearfix">
# <ul class="top-link">
#     <li><a href="https://www.timesjobs.com" class="link-active">TimesJobs</a></li>
#     <li><a href="http://jobbuzz.timesjobs.com" target="_blank">JobBuzz</a></li>
#     <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
#     <li><a href="https://ae.timesjobs.com" target="_blank">Gulf Jobs</a></li>
#     <li><a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">Career Insight</a></li>
#   </ul>
#
# <ul class="top-contact">
# 	 <li><i class="material-icons">call</i>0120 6358222</li>
#     <li>
#
#        	   <span id="chat-widget" onclick="window.fcWidget.open();window.fcWidget.show();"  class="live-chat">Live Chat (10am to 6pm IST)</span>
#
#     </li>
# 	</ul>
# 	</div>
# 	</div>
# 	<div class="ubility-wrap logo-section clearfix">
#
#
#
#
#
#
# 		<a itemprop="url" title="TIMESJOBS" href="https://www.timesjobs.com" class="top-tj-logo">
# 			<img src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" alt="TimesJobs" width="140" height="23" title="TimesJobs" itemprop="logo">
# 		</a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<script type="text/javascript">
# 				jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
# 			</script>
#
#
#
#
#
#
#
# 	  <ul class="main-tj-nav clearfix">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#
# </script>
# <!--- view notification section begin --->
#  <li class="notification viewnote">
# 	<a class='dropdown-button' href='#' data-activates='notifyDropdown'>
# 		<i class="material-icons left">notifications_none</i>
# 		<span id="notification_count" class="notif-count-new">1</span>&nbsp;
# 	</a>
# 	<div class="nav-drop viewnoteTab dropdown-content" id='notifyDropdown'>
# 	<div class="showdiv">
# 		<div id="non_loggedin" class="notif-not-logedin" style="display:none;">
# 			<div class="notif-welcm-msg clearfix">To see all recommended jobs, profile views, recruiter's contacted information, updates and more...</div>
# 	 			<div class='notif-act clearfix'>
#
#
#
# 						<button type='button' class='waves-effect waves-light btn red-bdr-btn' onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</button>
#
#
# 				<strong class='or'>or</strong>
# 				<a href="/candidate/register.html" class='waves-effect waves-light btn red-bdr-btn' >Register</a>
# 	    	</div>
# 	   	</div>
#
#
#
# 		<!-- INLINE LOGIN PAGE -->
#
# 		<div id="inline_login" class="notif-login-frm" style="display:none;">
#         <span class="notif-cls" title="Click to Hide"></span>
#
#
#
# 			  <strong>Login to View Notifications!</strong>
#
#
# 		<form action="/candidate/times_login?BeforeLoginUrl=notification&tab=1" method="post" name="loginFormNotification">
#
#
#
#
# 				    <input name="j_username" id="txtUseNameNotification" type="text" onblur="javascript:settextNotification('txtUseNameNotification');" onClick="filltxtNotification(txtUseNameNotification)" value="Enter Email id / Login id" class="txt2 defaultValue inpt-typ" size="42" />
#
#
# 		    <input name="j_password" type="password" value="" class="password_input_notification" size="42"  style="display:none" />
#             <input type="text" value="Enter Password" class="clearNotification" size="42" />
#             <div class="frgt-pass"><a href="javascript:forgotPasswordNotification();" class="fp">Forgot Password?</a></div>
#
# 	      <input class="" type="submit" onClick="javascript:return validateLoginFormNotification();" value="Login" />
#
#           <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
#            	      <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
#                   <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#        	      Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
# 	      </div>
#
#   	    <input type="hidden" name="notlogin" value="mytj">
# 		  <input type="hidden" name="_acegi_security_remember_me" value="yes">
# 	    </form>
# 	    </div>
#
# 		<!-- INLINE LOGIN PAGE -->
#                        <div id="base" style="display: none;" class="notif-main">
# 						   <ul>
# 	                       	   <li id="heading" class="heading clearfix">
# 	                       	   	<a id="heading-link" href="#"><span>Job Alerts(10)</span></a>
# 	                       	   </li>
# 		                       		<li id="base-li" style="display: none;"><a id="base-li-anchor" href="#">5 Matching Jobs <span id="base-li-time">3 hrs ago</span></a>
# 		                       		</li>
# 		                       		<span id="base-li-data" style="display: none;"  class="base_li"></span>
# 		                       </ul>
#                        </div>
#                        </div>
#           </div>
# 	  	  </li>
#
#                     <!--- view notification section ends here --->
#
#
# 	<script type="text/javascript">
#
# function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1662546890-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#
# </script>
#
#
#
#
#
#
#
#
#
# 				<li class="login-reg">
# 					<a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</a>
# 				</li>
#
#
# 		<li class="login-reg">
#
# 				<a href="/candidate/register.html?pageFlow=TJ_SEARCH">Register</a>
#
#
# 		</li>
#
# 	</ul>
#
#
# 	</div>
# </header>
# 	<!--bottom banner starts-->
#
#           <!--bottom banner ends-->
#
#
#
#
#
# 			<div class="open-search ">
#
#
#
#
#
#
# <div class="usability-srch clearfix">
#   <div class="main-srch-form clearfix">
# 	  <div id="errorMsgDiv" class="msg error" style="display:none">Please provide inputs for at least one field</div>
#        <form id="quickSearchBean" name="quickSearchBean" action="https://www.timesjobs.com/candidate/job-search.html" method="get"  onSubmit="return searchEngine.validateSearchForm(this);" >
#
#           	<input name="searchType" value="personalizedSearch" type="hidden">
#           	<input name="from" value="submit" type="hidden">
#           	<div class="auto-suggest-blk">
#
#
#
#
#             <input id="txtKeywords" name="txtKeywords" type="text"  value="Data Analyst" class="browser-default"/>
#             <div id="autoSuggestList" style="display:none;"><ul></ul></div><iframe id="FrameautoSuggestList" frameborder="0" style="display:none;"></iframe>
#             <div id="autoSuggestList2ndKeywordsListSFB" class="suggestionList srch-suggest" style="display:none;">
#               <h5>Suggested Keywords</h5>
#           <ul></ul></div>
#           </div>
#         <div class="auto-suggest-blk location-srch">
#
#
#
#
#   <input id="txtLocation" name="txtLocation" type="text" class="location-srch browser-default" value="India"/><div id="autoSuggestLocation" style="display:none;"><ul></ul></div><iframe id="FrameautoSuggestLocation" style="display:none" frameborder="0"></iframe></div>
#       <div class="srch-select">
#           <select id = "cboWorkExp1" name="cboWorkExp1" class="browser-default">
#
#
#
#                       <option value="-1" >Experience</option>
#
#
#
#
#
#                       <option value="0" selected='selected'>Entry Level</option>
#
#
#
#                       <option value="1" >1 year</option>
#
#
#
#                       <option value="2" >2 years</option>
#
#
#
#                       <option value="3" >3 years</option>
#
#
#
#                       <option value="4" >4 years</option>
#
#
#
#                       <option value="5" >5 years</option>
#
#
#
#                       <option value="6" >6 years</option>
#
#
#
#                       <option value="7" >7 years</option>
#
#
#
#                       <option value="8" >8 years</option>
#
#
#
#                       <option value="9" >9 years</option>
#
#
#
#                       <option value="10" >10 years</option>
#
#
#
#                       <option value="11" >11 years</option>
#
#
#
#                       <option value="12" >12 years</option>
#
#
#
#                       <option value="13" >13 years</option>
#
#
#
#                       <option value="14" >14 years</option>
#
#
#
#                       <option value="15" >15 years</option>
#
#
#
#                       <option value="16" >16 years</option>
#
#
#
#                       <option value="17" >17 years</option>
#
#
#
#                       <option value="18" >18 years</option>
#
#
#
#                       <option value="19" >19 years</option>
#
#
#
#                       <option value="20" >20 years</option>
#
#
#
#                       <option value="21" >20+ years</option>
#
#           </select>
#       </div>
#           <button class="waves-effect waves-light btn" value="Search" onclick="javascript:setAClickOnSearch();">Find Jobs</button>
#
#       </form>
#   </div>
# <div id="recentSearchId" class="recent-srchs home-srchptext srch-top-right" style="display: none;"></div>
#
#   <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
#     <div class="upload-res-txt clearfix">
#       <span class="upload-icon"></span>
#       <div class="upload-res-input">
#         <h5>New to Timesjobs?</h5>
#         <label class="upload-res-btn" id="uploadResume_basic">
#           upload your resume
#           <input name="resumeFile_basic" id="resumeFile_basic" size="25" type="file" />
#           </label>
#         <span id="uploadingResume_basic" style="display:none"><img src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif" alt="Uploading Resume"></span>
#         </div>
#       </div>
#   </div>
#
#    </div>
# <script type="text/javascript">
#   var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
# 			jQuery("#txtKeywords").val(text +","+ that);
# 			jQuery("#txtKeywords").focus();
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#   </script>
# 			</div>
#
#
#
#
#
# <script>
# var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
# </script>
#
#
# <script type='text/javascript'>
#
# //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#
# </script>
#
#
# <script type='text/javascript'>
#
# if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
# </script>
#
# <script type="text/javascript">
# 		$(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
# 	</script>
# <script>
# 	jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
# </script>
# 				<!-- Header Ends -->
#
# 				<!-- Content Starts   -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="ubility-wrap clearfix">
#     <!--Cluster related page inclusion start here-->
#
# 	<!--Cluster related page inclusion end here-->
#   <section class="ubility-lhs clearfix">
#
# <div id="search-result-cluster" class="inside-lhs">
# 	<div class="wht-bdr-bx tj-cluster">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <h4><i class="material-icons">sort</i>Refined By</h4>
# <!--  <div id="clusterRefineHistoryId"></div>-->
#
#
#
#
#
#
# <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
#
#   <div id="tj-tab-container-clusterId">
#     <div id="clusterDataInitial">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<ul class="collapsible" data-collapsible="expandable">
#
#
#   <li id="tabtc">
#
#
# 	  <div class="collapsible-header active"><h6>Companies</h6></div>
#     <div class="cluster-scroll collapsible-body">
#       <ul>
#         <div id="comp_show">
#
#
#
#
#             <li>
#
#
#
#
#
#
#
#                 <input id="com_0" type="checkbox" name="topCompanies"   onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&refineBy=dateWise&from=undo&actualTxtKeywords=Data Analyst&searchBy=0&rdoOperator=OR&searchType=personalizedSearch&txtLocation=India&luceneResultSize=25&postWeek=60&txtKeywords=0DQT0data analyst0DQT0&cboWorkExp1=0&undokey=compCluster&compCluster=citibank+india&gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&refineBy=dateWise&from=undo&actualTxtKeywords=Data Analyst&searchBy=0&rdoOperator=OR&searchType=personalizedSearch&txtLocation=India&luceneResultSize=25&postWeek=60&txtKeywords=0DQT0data analyst0DQT0&cboWorkExp1=0&undokey=compCluster&compCluster=citibank+india&gadLink=View Jobs By This Company','Citibank India');">
# 				<label for="com_0">
#                 <span title="Citibank India">
#                 Citibank India
#                 </span> <span class="grey-text">(6)</span></label>
#             </li>
#
#
#
#             <li>
#
#
#
#
#
#
#
# ...
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1263998740408550');
#   fbq('track', 'PageView');
#
#
# </script>
# <noscript>
# 	<img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1263998740408550&ev=PageView&noscript=1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
#
#
#
#
# <!-- New google pixel by sokrati -->
# <!-- Global site tag (gtag.js) - Google Ads: 1067146772 -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=AW-1067146772"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-1067146772');
# </script>
#
# <!-- New google pixel by sokrati -->
#
#
#
#
# <script>
# 	var parameter="";
# 	var regFlow="";
# 	var loginFlow="";
# 	var applyFlow="";
#
# 	regFlow="false";
# 	loginFlow="false";
# 	applyFlow="false";
#
# 	if(regFlow=="true")
# 	{
# 		parameter="_registrationFlow";
# 		ajaxController.trackCounter(parameter, "reg_3p9901_exp");
# 	}
# 	else if(loginFlow=="true"){
# 		var login = new RegExp("login.html", "i");
# 		if(!login.test(window.top.location) ){
# 			parameter="_loginFlow";
# 			ajaxController.trackCounter(parameter, "login_3p9901_exp");
# 		}
# 	}
#
# 	if(applyFlow=="true"){
# 		parameter="_applyFlow";
# 		ajaxController.trackCounter(parameter, "apply_3p9901_exp");
# 	}
# </script>
#
#
# <script type="text/javascript" src="//connect.facebook.net/en_US/sdk.js"></script>
#
#
#
# 	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/fb_auto_connect.js?v=7.1.7"></script>
#
#
#
#
#
#
#
#
#
#
# <!-- Columbia AdTech(TIL) Code start Here -->
# <script type='text/javascript'>
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://static.clmbtech.com/ase/2320/34/aa.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# <!-- Columbia AdTech(TIL) Code end Here -->
#
# <script type='text/javascript'>
# 	function freshWidgetCallback(){
# 		FreshWidget.init("", {"queryString": "&widgetType=popup&captcha=yes&searchArea=no", "backgroundImage": "https://www.ceoconnect.in/feedback/images/tj_feedback.gif", "utf8": "?", "widgetType": "popup", "buttonType": "image", "buttonText": "Support", "buttonColor": "black", "buttonBg": "#b8eaff", "alignment": "2", "offset": "145px", "formHeight": "500px", "captcha": "yes", "url": "https://timesjobs.freshdesk.com"} );
# 	}
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://assets.freshdesk.com/widget/freshwidget.js';
#          var x = document.getElementsByTagName('script')[0];
#          // most browsers
# 		s.onload = freshWidgetCallback;
# 		// IE 6 & 7
# 		s.onreadystatechange = function() {
# 			if (this.readyState == 'complete') {
# 				freshWidgetCallback();
# 			}
# 		}
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
#
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1727549374127582'); // Insert your pixel ID here.
# fbq('track', 'PageView');
#
# </script>
# <noscript><img height="1" width="1" style="display:none"
# src="https://www.facebook.com/tr?id=1727549374127582&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Facebook Pixel Code -->
# 				<!-- Footer Ends   -->
#
#
#
#
#
# 	<script type="text/javascript">
#         var GB_ROOT_DIR = "/candidate/greybox/";
#     </script>
#
#
# 	<link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" rel="stylesheet" type="text/css" media="all"/>
#
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.7"></script>
#
#
#
#
# 		<script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
#           <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
#
#
# <script type='text/javascript'>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#
#
# </script>
#
# <noscript>
#   <img src="https://sb.scorecardresearch.com/p?c1=2&c2=6036484&cv=2.0&cj=1" />
# </noscript>
#
# <script type='text/javascript'>
# /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
# </script>
#
# <script type='text/javascript'>
# 	jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
# </script>
# 	<script type="text/javascript">
# 	function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
# 	</script>
#
#
#
#
# <script type="text/javascript">
#
# var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
# </script>
# 	<!--Common Template Included in all files end here  -->
# 	<!--google analytics start-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
# </script>
# 	<!--google analytics ends-->
#
# 		<img src="https://tracking.sokrati.com/site?client_id=60&product_category=Site_Search" height="1" width="1" border="0" alt="" />
#
#
# <script type='text/javascript'>
#
# 	function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# 		</div>
#
# <script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js"></script>
# <div id="light-box-popup" class="modal">
# 	<span class="material-icons close-modal modal-action modal-close">close</span>
# 	<div class="modal-content" id="light-box-popup-content"></div>
# </div>
# <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<!--  ##########################  JobBuzz Ads  ################## -->
# 	</body>
# </html>

# %%
# creating a soup using BeautifulSoup, first importing it 
from bs4 import BeautifulSoup

# %%
# creating the soup object using the BeautifulSoup library and using the same 'lxml' parser for it
soup = BeautifulSoup(html_text, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html><head>
# <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.7" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js" type="text/javascript"></script>
# <link href="https://www.timesjobs.com/candidate/job-search.html" rel="canonical"/>
# <link href="https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&amp;from=submit&amp;txtKeywords=Data+Analyst&amp;txtLocation=India&amp;cboWorkExp1=0/&amp;sequence=2&amp;startPage=1" rel="next"/>
# <title>data analyst Jobs in India  with Entry Level experience - TimesJobs</title>
# <meta content="Jobs in data analyst in India  with Entry Level experience. Search and apply jobs online at Timesjobs.com" name="description"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');</script>
# <!-- End Google Tag Manager -->
# <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript"></script>
# <script>
#           //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#         </script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="C4P83-FLD8C-N9VTA-RP2SP-ZADRK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"C4P83-FLD8C-N9VTA-RP2SP-ZADRK";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="nlgy2qyxhjo3ayyyopfa-f-6a5bc68da-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"32","ak.cp":"1277284","ak.ai":parseInt("765140",10),"ak.ol":"0","ak.cr":96,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"2094386b","ak.r":35512,"ak.a2":n,"ak.m":"j","ak.n":"essl","ak.bpcip":"106.205.141.0","ak.cport":61881,"ak.gh":"23.58.93.172","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1662546890","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"6","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body>
# <div id="site">
# <!-- Header Starts -->
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script src="https://wchat.freshchat.com/js/widget.js" type="text/javascript"></script>
# <script>
# window.fcWidget.init({
# token: "d7130618-a917-400b-804c-bdf44d8d178b",
# host: "https://wchat.freshchat.com",
# config: {
# headerProperty: {
# hideChatButton: true
# }
#         }
# });
#
# </script>
# <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
# <script src="https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js" type="text/javascript"></script>
# <div class="msg notify" id="fb_connect_suggest" style="display: none;">
# 		Dear Jobseeker, Find millions of jobs on single click.
# 		<span id="fb_auto_connect"><a href="javascript:fconnect_auto();"><img alt="fconnect" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png"/></a></span>
# <span class="big-cls cls-icn" onclick="javascript:ack_fbconnect_cancel();" title="Click to Hide"><i class="material-icons">close</i></span>
# <span id="fb_connect_status"></span>
# </div>
# <div class="msg success" id="fb_connect_success" style="display: none;">
# 			Congratulations! You have been logged in via Facebook
# 		</div>
# <header class="main-header">
# <div class="top-header">
# <div class="ubility-wrap clearfix">
# <ul class="top-link">
# <li><a class="link-active" href="https://www.timesjobs.com">TimesJobs</a></li>
# <li><a href="http://jobbuzz.timesjobs.com" target="_blank">JobBuzz</a></li>
# <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
# <li><a href="https://ae.timesjobs.com" target="_blank">Gulf Jobs</a></li>
# <li><a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">Career Insight</a></li>
# </ul>
# <ul class="top-contact">
# <li><i class="material-icons">call</i>0120 6358222</li>
# <li>
# <span class="live-chat" id="chat-widget" onclick="window.fcWidget.open();window.fcWidget.show();">Live Chat (10am to 6pm IST)</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="ubility-wrap logo-section clearfix">
# <a class="top-tj-logo" href="https://www.timesjobs.com" itemprop="url" title="TIMESJOBS">
# <img alt="TimesJobs" height="23" itemprop="logo" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" title="TimesJobs" width="140"/>
# </a>
# <script type="text/javascript">
# 				jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
# 			</script>
# <ul class="main-tj-nav clearfix">
# <script type="text/javascript">
# var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#
# </script>
# <!--- view notification section begin --->
# <li class="notification viewnote">
# <a class="dropdown-button" data-activates="notifyDropdown" href="#">
# <i class="material-icons left">notifications_none</i>
# <span class="notif-count-new" id="notification_count">1</span>
# 	</a>
# <div class="nav-drop viewnoteTab dropdown-content" id="notifyDropdown">
# <div class="showdiv">
# <div class="notif-not-logedin" id="non_loggedin" style="display:none;">
# <div class="notif-welcm-msg clearfix">To see all recommended jobs, profile views, recruiter's contacted information, updates and more...</div>
# <div class="notif-act clearfix">
# <button class="waves-effect waves-light btn red-bdr-btn" onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');" type="button">Login</button>
# <strong class="or">or</strong>
# <a class="waves-effect waves-light btn red-bdr-btn" href="/candidate/register.html">Register</a>
# </div>
# </div>
# <!-- INLINE LOGIN PAGE -->
# <div class="notif-login-frm" id="inline_login" style="display:none;">
# <span class="notif-cls" title="Click to Hide"></span>
# <strong>Login to View Notifications!</strong>
# <form action="/candidate/times_login?BeforeLoginUrl=notification&amp;tab=1" method="post" name="loginFormNotification">
# <input class="txt2 defaultValue inpt-typ" id="txtUseNameNotification" name="j_username" onblur="javascript:settextNotification('txtUseNameNotification');" onclick="filltxtNotification(txtUseNameNotification)" size="42" type="text" value="Enter Email id / Login id"/>
# <input class="password_input_notification" name="j_password" size="42" style="display:none" type="password" value=""/>
# <input class="clearNotification" size="42" type="text" value="Enter Password"/>
# <div class="frgt-pass"><a class="fp" href="javascript:forgotPasswordNotification();">Forgot Password?</a></div>
# <input class="" onclick="javascript:return validateLoginFormNotification();" type="submit" value="Login"/>
# <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
# <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
# <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#        	      Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
# 	      </div>
# <input name="notlogin" type="hidden" value="mytj"/>
# <input name="_acegi_security_remember_me" type="hidden" value="yes"/>
# </form>
# </div>
# <!-- INLINE LOGIN PAGE -->
# <div class="notif-main" id="base" style="display: none;">
# <ul>
# <li class="heading clearfix" id="heading">
# <a href="#" id="heading-link"><span>Job Alerts(10)</span></a>
# </li>
# <li id="base-li" style="display: none;"><a href="#" id="base-li-anchor">5 Matching Jobs <span id="base-li-time">3 hrs ago</span></a>
# </li>
# <span class="base_li" id="base-li-data" style="display: none;"></span>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <!--- view notification section ends here --->
# <script type="text/javascript">
#
# function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1662546890-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#
# </script>
# <li class="login-reg">
# <a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</a>
# </li>
# <li class="login-reg">
# <a href="/candidate/register.html?pageFlow=TJ_SEARCH">Register</a>
# </li>
# </ul>
# </div>
# </header>
# <!--bottom banner starts-->
# <!--bottom banner ends-->
# <div class="open-search">
# <div class="usability-srch clearfix">
# <div class="main-srch-form clearfix">
# <div class="msg error" id="errorMsgDiv" style="display:none">Please provide inputs for at least one field</div>
# <form action="https://www.timesjobs.com/candidate/job-search.html" id="quickSearchBean" method="get" name="quickSearchBean" onsubmit="return searchEngine.validateSearchForm(this);">
# <input name="searchType" type="hidden" value="personalizedSearch"/>
# <input name="from" type="hidden" value="submit"/>
# <div class="auto-suggest-blk">
# <input class="browser-default" id="txtKeywords" name="txtKeywords" type="text" value="Data Analyst"/>
# <div id="autoSuggestList" style="display:none;"><ul></ul></div><iframe frameborder="0" id="FrameautoSuggestList" style="display:none;"></iframe>
# <div class="suggestionList srch-suggest" id="autoSuggestList2ndKeywordsListSFB" style="display:none;">
# <h5>Suggested Keywords</h5>
# <ul></ul></div>
# </div>
# <div class="auto-suggest-blk location-srch">
# <input class="location-srch browser-default" id="txtLocation" name="txtLocation" type="text" value="India"/><div id="autoSuggestLocation" style="display:none;"><ul></ul></div><iframe frameborder="0" id="FrameautoSuggestLocation" style="display:none"></iframe></div>
# <div class="srch-select">
# <select class="browser-default" id="cboWorkExp1" name="cboWorkExp1">
# <option value="-1">Experience</option>
# <option selected="selected" value="0">Entry Level</option>
# <option value="1">1 year</option>
# <option value="2">2 years</option>
# <option value="3">3 years</option>
# <option value="4">4 years</option>
# <option value="5">5 years</option>
# <option value="6">6 years</option>
# <option value="7">7 years</option>
# <option value="8">8 years</option>
# <option value="9">9 years</option>
# <option value="10">10 years</option>
# <option value="11">11 years</option>
# <option value="12">12 years</option>
# <option value="13">13 years</option>
# <option value="14">14 years</option>
# <option value="15">15 years</option>
# <option value="16">16 years</option>
# <option value="17">17 years</option>
# <option value="18">18 years</option>
# <option value="19">19 years</option>
# <option value="20">20 years</option>
# <option value="21">20+ years</option>
# </select>
# </div>
# <button class="waves-effect waves-light btn" onclick="javascript:setAClickOnSearch();" value="Search">Find Jobs</button>
# </form>
# </div>
# <div class="recent-srchs home-srchptext srch-top-right" id="recentSearchId" style="display: none;"></div>
# <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
# <div class="upload-res-txt clearfix">
# <span class="upload-icon"></span>
# <div class="upload-res-input">
# <h5>New to Timesjobs?</h5>
# <label class="upload-res-btn" id="uploadResume_basic">
#           upload your resume
#           <input id="resumeFile_basic" name="resumeFile_basic" size="25" type="file"/>
# </label>
# <span id="uploadingResume_basic" style="display:none"><img alt="Uploading Resume" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif"/></span>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
# 			jQuery("#txtKeywords").val(text +","+ that);
# 			jQuery("#txtKeywords").focus();
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#   </script>
# </div>
# <script>
# var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
# </script>
# <script type="text/javascript">
#
# //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#
# </script>
# <script type="text/javascript">
#
# if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
# </script>
# <script type="text/javascript">
# 		$(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
# 	</script>
# <script>
# 	jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
# </script>
# <!-- Header Ends -->
# <!-- Content Starts   -->
# <div class="ubility-wrap clearfix">
# <!--Cluster related page inclusion start here-->
# <!--Cluster related page inclusion end here-->
# <section class="ubility-lhs clearfix">
# <div class="inside-lhs" id="search-result-cluster">
# <div class="wht-bdr-bx tj-cluster">
# <h4><i class="material-icons">sort</i>Refined By</h4>
# <!--  <div id="clusterRefineHistoryId"></div>-->
# <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
# <div id="tj-tab-container-clusterId">
# <div id="clusterDataInitial">
# <ul class="collapsible" data-collapsible="expandable">
# <li id="tabtc">
# <div class="collapsible-header active"><h6>Companies</h6></div>
# <div class="cluster-scroll collapsible-body">
# <ul>
# <div id="comp_show">
# <li>
# <input id="com_0" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=citibank+india&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=citibank+india&amp;gadLink=View Jobs By This Company','Citibank India');" type="checkbox"/>
# <label for="com_0">
# <span title="Citibank India">
#                 Citibank India
#                 </span> <span class="grey-text">(6)</span></label>
# </li>
# <li>
# <input id="com_1" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=ion+trading+india+pvt.+ltd.&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=ion+trading+india+pvt.+ltd.&amp;gadLink=View Jobs By This Company','Ion Trading India Pvt. Ltd.');" type="checkbox"/>
# <label for="com_1">
# <span title="Ion Trading India Pvt. Ltd.">
#                 Ion Trading India Pvt. Ltd.
#                 </span> <span class="grey-text">(6)</span></label>
# </li>
# <li>
# <input id="com_2" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=applycup+hiring+solutions+llp&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=applycup+hiring+solutions+llp&amp;gadLink=View Jobs By This Company','Applycup Hiring Solutions Llp');" type="checkbox"/>
# <label for="com_2">
# <span title="Applycup Hiring Solutions Llp">
#                 Applycup Hiring Solutions Llp
#                 </span> <span class="grey-text">(5)</span></label>
# </li>
# <li>
# <input id="com_3" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=rgf+professional&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=rgf+professional&amp;gadLink=View Jobs By This Company','Rgf Professional');" type="checkbox"/>
# <label for="com_3">
# <span title="Rgf Professional">
#                 Rgf Professional
#                 </span> <span class="grey-text">(3)</span></label>
# </li>
# <li>
# <input id="com_4" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=amazon+india+pvt+ltd&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Data Analyst&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=India&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=0DQT0data analyst0DQT0&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=amazon+india+pvt+ltd&amp;gadLink=View Jobs By This Company','Amazon India Pvt Ltd');" type="checkbox"/>
# <label for="com_4">
# <span title="Amazon India Pvt Ltd">
#                 Amazon India Pvt Ltd
#                 </span> <span class="grey-text">(2)</span></label>
# </li>
# <li>
# ...
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1263998740408550');
#   fbq('track', 'PageView');
#
#
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1263998740408550&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <!-- New google pixel by sokrati -->
# <!-- Global site tag (gtag.js) - Google Ads: 1067146772 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1067146772"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-1067146772');
# </script>
# <!-- New google pixel by sokrati -->
# <script>
# 	var parameter="";
# 	var regFlow="";
# 	var loginFlow="";
# 	var applyFlow="";
#
# 	regFlow="false";
# 	loginFlow="false";
# 	applyFlow="false";
#
# 	if(regFlow=="true")
# 	{
# 		parameter="_registrationFlow";
# 		ajaxController.trackCounter(parameter, "reg_3p9901_exp");
# 	}
# 	else if(loginFlow=="true"){
# 		var login = new RegExp("login.html", "i");
# 		if(!login.test(window.top.location) ){
# 			parameter="_loginFlow";
# 			ajaxController.trackCounter(parameter, "login_3p9901_exp");
# 		}
# 	}
#
# 	if(applyFlow=="true"){
# 		parameter="_applyFlow";
# 		ajaxController.trackCounter(parameter, "apply_3p9901_exp");
# 	}
# </script>
# <script src="//connect.facebook.net/en_US/sdk.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/fb_auto_connect.js?v=7.1.7" type="text/javascript"></script>
# <!-- Columbia AdTech(TIL) Code start Here -->
# <script type="text/javascript">
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://static.clmbtech.com/ase/2320/34/aa.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# <!-- Columbia AdTech(TIL) Code end Here -->
# <script type="text/javascript">
# 	function freshWidgetCallback(){
# 		FreshWidget.init("", {"queryString": "&widgetType=popup&captcha=yes&searchArea=no", "backgroundImage": "https://www.ceoconnect.in/feedback/images/tj_feedback.gif", "utf8": "?", "widgetType": "popup", "buttonType": "image", "buttonText": "Support", "buttonColor": "black", "buttonBg": "#b8eaff", "alignment": "2", "offset": "145px", "formHeight": "500px", "captcha": "yes", "url": "https://timesjobs.freshdesk.com"} );
# 	}
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://assets.freshdesk.com/widget/freshwidget.js';
#          var x = document.getElementsByTagName('script')[0];
#          // most browsers
# 		s.onload = freshWidgetCallback;
# 		// IE 6 & 7
# 		s.onreadystatechange = function() {
# 			if (this.readyState == 'complete') {
# 				freshWidgetCallback();
# 			}
# 		}
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1727549374127582'); // Insert your pixel ID here.
# fbq('track', 'PageView');
#
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1727549374127582&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Footer Ends   -->
# <script type="text/javascript">
#         var GB_ROOT_DIR = "/candidate/greybox/";
#     </script>
# <link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.7" type="text/javascript"></script>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
# <script type="text/javascript">
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#
#
# </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6036484&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script type="text/javascript">
# /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
# </script>
# <script type="text/javascript">
# 	jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
# </script>
# <script type="text/javascript">
# 	function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
# 	</script>
# <script type="text/javascript">
#
# var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
# </script>
# <!--Common Template Included in all files end here  -->
# <!--google analytics start-->
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
# </script>
# <!--google analytics ends-->
# <img alt="" border="0" height="1" src="https://tracking.sokrati.com/site?client_id=60&amp;product_category=Site_Search" width="1"/>
# <script type="text/javascript">
#
# 	function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# </div>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js" type="text/javascript"></script>
# <div class="modal" id="light-box-popup">
# <span class="material-icons close-modal modal-action modal-close">close</span>
# <div class="modal-content" id="light-box-popup-content"></div>
# </div>
# <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
# <!--  ##########################  JobBuzz Ads  ################## -->
# </body>
# </html>

# %%
# here we used the tag li and copied the class_ name from the inspect html site of the particular item

jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')

# %%
print(jobs)
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-ikomet-technology-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-uYgM1Mifhr1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68834111','macros  ,  visualization  ,  bi  ,  data analyst  ,  vba','Chennai','0 - 3','IT Software : Software Products &amp; Services','1' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     ikomet Technology Solutions Pvt. Ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Chennai">Chennai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Knowledge on R Programming ,  VBA ,  MacrosProficient in Microsoft excel with exposure on Pivot tables ,  Vlookup ,  logic formulasPresenting various analysis and reports to t... <a href="https://www.timesjobs.com/job-detail/data-analyst-ikomet-technology-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-uYgM1Mifhr1zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           macros  ,  visualization  ,  bi  ,  <strong class="blkclor">data</strong> <strong class="blkclor">analyst</strong>  ,  vba
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Chennai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68834111">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68834111','adId=uYgM1Mifhr1zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68834111','macros  ,  visualization  ,  bi  ,  data analyst  ,  vba','Chennai','0 - 3','IT Software : Software Products &amp; Services','1')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-anr-software-pvt-ltd-noida-greater-noida-0-to-1-yrs-jobid-wiKqbbFOouJzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','64686972','data analytics  ,  information management  ,  sas  ,  spss  ,  data analyst  ,  sql  ,  data science  ,  written communication','Noida/Greater Noida','0 - 1','IT Software : Software Products &amp; Services','2' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     ANR SOFTWARE PVT LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Noida/Greater Noida">Noida/Greater Noida</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Data AnalystExperience: 0 to 1 YearsEligibility  &amp;  Job Description Eligibility: Bachelor degree in Mathematics ,  Computer Science ,  Information Management or StatisticsAny ... <a href="https://www.timesjobs.com/job-detail/data-analyst-anr-software-pvt-ltd-noida-greater-noida-0-to-1-yrs-jobid-wiKqbbFOouJzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
# <strong class="blkclor">data</strong> analytics  ,  information management  ,  sas  ,  spss  ,  <strong class="blkclor">data</strong> <strong class="blkclor">analyst</strong>  ,  sql  ,  <strong class="blkclor">data</strong> science  ,  written communication
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Noida/Greater Noida
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_64686972">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('64686972','adId=wiKqbbFOouJzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','64686972','data analytics  ,  information management  ,  sas  ,  spss  ,  data analyst  ,  sql  ,  data science  ,  written communication','Noida/Greater Noida','0 - 1','IT Software : Software Products &amp; Services','2')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-legalwiz-in-private-limited-ahmedabad-0-to-1-yrs-jobid-Yg11HKMOaORzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67397100','information technology  ,  data mining  ,  data warehousing  ,  storage  ,  dashboards  ,  data analyst  ,  tableau  ,  data visualization','Ahmedabad','0 - 1','IT Software : Software Products &amp; Services','3' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     legalwiz.in private limited
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad">Ahmedabad</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Data AnalystExperience: 0-1 yearsResponsibilities:Mine and analyze data from databases to drive optimization and improvement of product development ,  marketing techniques and... <a href="https://www.timesjobs.com/job-detail/data-analyst-legalwiz-in-private-limited-ahmedabad-0-to-1-yrs-jobid-Yg11HKMOaORzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           information technology  ,  <strong class="blkclor">data</strong> mining  ,  <strong class="blkclor">data</strong> warehousing  ,  storage  ,  dashboards  ,  <strong class="blkclor">data</strong> <strong class="blkclor">analyst</strong>  ,  tableau  ,  <strong class="blkclor">data</strong> visualization
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Ahmedabad
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67397100">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67397100','adId=Yg11HKMOaORzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67397100','information technology  ,  data mining  ,  data warehousing  ,  storage  ,  dashboards  ,  data analyst  ,  tableau  ,  data visualization','Ahmedabad','0 - 1','IT Software : Software Products &amp; Services','3')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-anz-grindlays-bank-bengaluru-bangalore-0-to-3-yrs-jobid-mt1UyJkYdzxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68985982','data warehousing  ,  sql  ,  database  ,  data analytics  ,  data analysis  ,  oracle  ,  business analysis  ,  data analyst  ,  tableau  ,  data governance  ,  analyst','Bengaluru / Bangalore','0 - 3','IT Software : Software Products &amp; Services','4' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     ANZ GRINDLAYS BANK
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# About the roleAt ANZ our purpose is to shape a world where people and communities thrive. Were making this happen by improving our customers financial wellbeing so they can ac... <a href="https://www.timesjobs.com/job-detail/data-analyst-anz-grindlays-bank-bengaluru-bangalore-0-to-3-yrs-jobid-mt1UyJkYdzxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
# <strong class="blkclor">data</strong> warehousing  ,  sql  ,  database  ,  <strong class="blkclor">data</strong> analytics  ,  <strong class="blkclor">data</strong> analysis  ,  oracle  ,  business analysis  ,  <strong class="blkclor">data</strong> <strong class="blkclor">analyst</strong>  ,  tableau  ,  <strong class="blkclor">data</strong> governance  ,  <strong class="blkclor">analyst</strong>
# </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68985982">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68985982','adId=mt1UyJkYdzxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68985982','data warehousing  ,  sql  ,  database  ,  data analytics  ,  data analysis  ,  oracle  ,  business analysis  ,  data analyst  ,  tableau  ,  data governance  ,  analyst','Bengaluru / Bangalore','0 - 3','IT Software : Software Products &amp; Services','4')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 4 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-ion-trading-india-pvt-ltd-noida-greater-noida-0-to-3-yrs-jobid-QDeB2K4ih45zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68716403','bi  ,  dashboards  ,  sql  ,  trading systems  ,  software engineering  ,  data visualization  ,  predictive analysis  ,  electronic trading  ,  data analysis  ,  consulting  ,  data analyst  ,  written communication  ,  infrastructure','Noida/Greater Noida','0 - 3','IT Software : Software Products &amp; Services','5' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     ion trading india pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Noida/Greater Noida">Noida/Greater Noida</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Perform exploratory ,  descriptive and predictive analysis on data to draw actionable insights related to customers and products ,  and make better recommendations. Working wi... <a href="https://www.timesjobs.com/job-detail/data-analyst-ion-trading-india-pvt-ltd-noida-greater-noida-0-to-3-yrs-jobid-QDeB2K4ih45zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           bi  ,  dashboards  ,  sql  ,  trading systems  ,  software engineering  ,  <strong class="blkclor">data</strong> visualization  ,  predictive analysis  ,  electronic trading  ,  <strong class="blkclor">data</strong> analysis  ,  consulting  ,  <strong class="blkclor">data</strong> <strong class="blkclor">analyst</strong>  ,  written communication  ,  infrastructure
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Noida/Greater Noida
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68716403">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68716403','adId=QDeB2K4ih45zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68716403','bi  ,  dashboards  ,  sql  ,  trading systems  ,  software engineering  ,  data visualization  ,  predictive analysis  ,  electronic trading  ,  data analysis  ,  consulting  ,  data analyst  ,  written communication  ,  infrastructure','Noida/Greater Noida','0 - 3','IT Software : Software Products &amp; Services','5')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-busisol-sourcing-india-pvt-ltd-mumbai-0-to-3-yrs-jobid-ARJVvDp1IFtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65501144','charts  ,  data mining  ,  formulas  ,  relational database  ,  sql server  ,  reporting services','Mumbai','0 - 3','IT Software : Software Products &amp; Services','6' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     BUSISOL SOURCING INDIA PVT. LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Mumbai">Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Dear Candidate ,  We had an opportunity as Data Analyst - Mumbai Looking for candidate with experience in - Must have knowledge of MSBI on reporting services  ( SSIS )  - Must... <a href="https://www.timesjobs.com/job-detail/data-analyst-busisol-sourcing-india-pvt-ltd-mumbai-0-to-3-yrs-jobid-ARJVvDp1IFtzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           charts  ,  <strong class="blkclor">data</strong> mining  ,  formulas  ,  relational database  ,  sql server  ,  reporting services
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Mumbai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65501144">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65501144','adId=ARJVvDp1IFtzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65501144','charts  ,  data mining  ,  formulas  ,  relational database  ,  sql server  ,  reporting services','Mumbai','0 - 3','IT Software : Software Products &amp; Services','6')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analysts-kudosindia-mumbai-0-to-3-yrs-jobid-v48SsInbeSRzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66859115','test cases  ,  database  ,  metrics  ,  component testing','Mumbai','0 - 3','IT Software : Software Products &amp; Services','7' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analysts</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     kudosindia
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Mumbai">Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Data AnalystsJob descriptionInterpret and analyze data to identify patterns and correlations among the various data points.mapping and tracing data from system to system in or... <a href="https://www.timesjobs.com/job-detail/data-analysts-kudosindia-mumbai-0-to-3-yrs-jobid-v48SsInbeSRzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           test cases  ,  database  ,  metrics  ,  component testing
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Mumbai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66859115">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66859115','adId=v48SsInbeSRzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66859115','test cases  ,  database  ,  metrics  ,  component testing','Mumbai','0 - 3','IT Software : Software Products &amp; Services','7')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-busisol-sourcing-india-pvt-ltd-delhi-0-to-3-yrs-jobid-8prYmLkFDLdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65501137','reports  ,  charts  ,  data mining  ,  formulas  ,  reporting services  ,  relational database  ,  sql server','Delhi','0 - 3','IT Software : Software Products &amp; Services','8' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     BUSISOL SOURCING INDIA PVT. LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Delhi">Delhi</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job description : We are looking for an experienced Data Analyst ,  who possesses most or all of the following qualities: - Self-starter ,  able to work on his own with little... <a href="https://www.timesjobs.com/job-detail/data-analyst-busisol-sourcing-india-pvt-ltd-delhi-0-to-3-yrs-jobid-8prYmLkFDLdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           reports  ,  charts  ,  <strong class="blkclor">data</strong> mining  ,  formulas  ,  reporting services  ,  relational database  ,  sql server
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Delhi
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65501137">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65501137','adId=8prYmLkFDLdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65501137','reports  ,  charts  ,  data mining  ,  formulas  ,  reporting services  ,  relational database  ,  sql server','Delhi','0 - 3','IT Software : Software Products &amp; Services','8')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-hexanika-pune-0-to-3-yrs-jobid-uV1krqn6UrlzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66311252','test data  ,  sql queries  ,  testing  ,  sql','Pune','0 - 3','IT Software : Software Products &amp; Services','9' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     Hexanika
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune">Pune</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job Description: We are looking to hire a Data Analyst to join our data team. Your responsibility would include for developing reports ,  and troubleshooting data issues. To d... <a href="https://www.timesjobs.com/job-detail/data-analyst-hexanika-pune-0-to-3-yrs-jobid-uV1krqn6UrlzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           test <strong class="blkclor">data</strong>  ,  sql queries  ,  testing  ,  sql
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Pune
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66311252">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66311252','adId=uV1krqn6UrlzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66311252','test data  ,  sql queries  ,  testing  ,  sql','Pune','0 - 3','IT Software : Software Products &amp; Services','9')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-applycup-hiring-solutions-llp-delhi-delhi-ncr-0-to-2-yrs-jobid-0jkIVQHYHxNzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65601828','database  ,  bi  ,  sql','Delhi,  Delhi/NCR','0 - 2','IT Software : Software Products &amp; Services','10' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     APPLYCUP HIRING SOLUTIONS LLP
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 2 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Delhi,  Delhi/NCR">Delhi,  Delhi/NCR</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Data AnalystDelhi ,  Delhi Qualification : Any Graduate Experience : 0 - 2 YearsSkills : Data Analyst ,  SQL ,  Query Database ,  BI tool ,  MSFT Word ,  Excel  &amp;  Powerpoint ... <a href="https://www.timesjobs.com/job-detail/data-analyst-applycup-hiring-solutions-llp-delhi-delhi-ncr-0-to-2-yrs-jobid-0jkIVQHYHxNzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           database  ,  bi  ,  sql
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Delhi,  Delhi/NCR
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65601828">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65601828','adId=0jkIVQHYHxNzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65601828','database  ,  bi  ,  sql','Delhi,  Delhi/NCR','0 - 2','IT Software : Software Products &amp; Services','10')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-hyrefox-consultants-jaipur-0-to-3-yrs-jobid-KwT1r6nTXxFzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68952744','excel  ,  reports  ,  reporting  ,  monthly reports','Jaipur','0 - 3','Accounting  /  Tax  /  Company Secretary  /  Audit','11' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     HyreFox Consultants
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Jaipur">Jaipur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Must Have - Advance Excel Expertise Create business reports and process all data extracts and imports; ensuring accuracy and attention to detail at all times Collate and produ... <a href="https://www.timesjobs.com/job-detail/data-analyst-hyrefox-consultants-jaipur-0-to-3-yrs-jobid-KwT1r6nTXxFzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           excel  ,  reports  ,  reporting  ,  monthly reports
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Jaipur
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68952744">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68952744','adId=KwT1r6nTXxFzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68952744','excel  ,  reports  ,  reporting  ,  monthly reports','Jaipur','0 - 3','Accounting  /  Tax  /  Company Secretary  /  Audit','11')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-advanced-risk-analytics-private-limited-pune-0-to-3-yrs-jobid-TmPblskT8fVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65511980','visualizing data  ,  data collection  ,  Flood data','Pune','0 - 3','IT Software : Software Products &amp; Services','12' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     advanced risk analytics private limited
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune">Pune</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Candidate should have:Knowledge of catastrophe data collection like Flood data ,  Earthquake data ,  Image processing data from satellite ,  LIDAR and DroneSynthesizing and vi... <a href="https://www.timesjobs.com/job-detail/data-analyst-advanced-risk-analytics-private-limited-pune-0-to-3-yrs-jobid-TmPblskT8fVzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           visualizing <strong class="blkclor">data</strong>  ,  <strong class="blkclor">data</strong> collection  ,  Flood <strong class="blkclor">data</strong>
# </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Pune
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65511980">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65511980','adId=TmPblskT8fVzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65511980','visualizing data  ,  data collection  ,  Flood data','Pune','0 - 3','IT Software : Software Products &amp; Services','12')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-senior-data-analyst-data-analyst-appsoft-solutions-ahmedabad-bengaluru-bangalore-chennai-delhi-delhi-ncr-0-to-3-yrs-jobid-wcZ__SLASH__KEwZAgtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67921060','Data Analyst  ,   Senior Data Analyst  ,   Data Analyst - Tech Lead  ,  data profiling  ,  data models  ,  data collection','Ahmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Delhi/NCR','0 - 3','IT Software : Software Products &amp; Services','13' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong>  ,  Senior <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong>  ,  <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     AppSoft Solutions
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=zMgb35ZSTWOeSlwSIBDKHw==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li><i class="material-icons rupee">₹</i>Rs 3.50 - 6.50 Lacs p.a.</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Delhi/NCR">Ahmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Delhi/NCR</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job Description:Data Analyst  /  Senior Data Analyst  /  Data Analyst - Tech LeadVery Urgent RequirementIf Your Profile Matches The Above Requirement And If You're Interested ... <a href="https://www.timesjobs.com/job-detail/data-analyst-senior-data-analyst-data-analyst-appsoft-solutions-ahmedabad-bengaluru-bangalore-chennai-delhi-delhi-ncr-0-to-3-yrs-jobid-wcZ__SLASH__KEwZAgtzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong>  ,   Senior <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong>  ,   <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong> - Tech Lead  ,  <strong class="blkclor">data</strong> profiling  ,  <strong class="blkclor">data</strong> models  ,  <strong class="blkclor">data</strong> collection
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Ahmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Delhi/NCR
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67921060">
# <button class="waves-effect waves-light btn" id="apply_67921060" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('67921060','INT','TJPFSRP');logViewUSBT('apply','67921060','Data Analyst  ,   Senior Data Analyst  ,   Data Analyst - Tech Lead  ,  data profiling  ,  data models  ,  data collection','Ahmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Delhi/NCR','0 - 3','IT Software : Software Products &amp; Services','13')">Apply</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 3 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-cpr-rgf-professional-gurgaon-0-to-3-yrs-jobid-bqKLc2QHnC5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66562045','team player  ,   generate hypotheses  ,   Data Analyst','Gurgaon','0 - 3','IT Software : Software Products &amp; Services','14' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong>: CPR</a> </h2>
# <h3 class="joblist-comp-name">
#     RGF Professional
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Gurgaon">Gurgaon</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job Description Take responsibility for assigned work streams and generate hypotheses. Effectively understand the work plan and execute itIdentify and apply the relevant analy... <a href="https://www.timesjobs.com/job-detail/data-analyst-cpr-rgf-professional-gurgaon-0-to-3-yrs-jobid-bqKLc2QHnC5zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           team player  ,   generate hypotheses  ,   <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong>
# </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Gurgaon
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66562045">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66562045','adId=bqKLc2QHnC5zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66562045','team player  ,   generate hypotheses  ,   Data Analyst','Gurgaon','0 - 3','IT Software : Software Products &amp; Services','14')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-looker-applycup-hiring-solutions-llp-delhi-delhi-ncr-0-to-1-yrs-jobid-Vkgb2ZtqhwFzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65599920','visualization  ,  business requirements  ,  bi  ,  dashboards  ,  data analyst  ,  sql  ,  tableau  ,  security','Delhi,  Delhi/NCR','0 - 1','IT Software : Software Products &amp; Services','15' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong> - Looker</a> </h2>
# <h3 class="joblist-comp-name">
#     APPLYCUP HIRING SOLUTIONS LLP
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Delhi,  Delhi/NCR">Delhi,  Delhi/NCR</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Interacting with clients ,  to understand their needs and come up with an end-to-end solutionTranslate business requirements to actionable data tasks  ( English  SQL ) Use Loo... <a href="https://www.timesjobs.com/job-detail/data-analyst-looker-applycup-hiring-solutions-llp-delhi-delhi-ncr-0-to-1-yrs-jobid-Vkgb2ZtqhwFzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           visualization  ,  business requirements  ,  bi  ,  dashboards  ,  <strong class="blkclor">data</strong> <strong class="blkclor">analyst</strong>  ,  sql  ,  tableau  ,  security
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Delhi,  Delhi/NCR
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65599920">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65599920','adId=Vkgb2ZtqhwFzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65599920','visualization  ,  business requirements  ,  bi  ,  dashboards  ,  data analyst  ,  sql  ,  tableau  ,  security','Delhi,  Delhi/NCR','0 - 1','IT Software : Software Products &amp; Services','15')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-sql-applycup-hiring-solutions-llp-surat-0-to-3-yrs-jobid-HG7emqsRg3BzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65600711','data analysis  ,  ms access  ,  data analyst  ,  sql  ,  database  ,  vba','Surat','0 - 3','IT Software : Software Products &amp; Services','16' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong>  ( SQL ) </a> </h2>
# <h3 class="joblist-comp-name">
#     APPLYCUP HIRING SOLUTIONS LLP
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Surat">Surat</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Qualification : Bachelor's degree ,  and a master's degree inmath ,  statistics ,  computer science ,  or something closely related to their field. Experience : 0 - 3 YearsSki... <a href="https://www.timesjobs.com/job-detail/data-analyst-sql-applycup-hiring-solutions-llp-surat-0-to-3-yrs-jobid-HG7emqsRg3BzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
# <strong class="blkclor">data</strong> analysis  ,  ms access  ,  <strong class="blkclor">data</strong> <strong class="blkclor">analyst</strong>  ,  sql  ,  database  ,  vba
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Surat
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65600711">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65600711','adId=HG7emqsRg3BzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65600711','data analysis  ,  ms access  ,  data analyst  ,  sql  ,  database  ,  vba','Surat','0 - 3','IT Software : Software Products &amp; Services','16')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-looker-vinayak-solutions-pvt-limited-delhi-0-to-1-yrs-jobid-Qz3d8X1UiJdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68713650','visualization  ,  data analysis  ,  business requirements  ,  consulting  ,  bi  ,  dashboards  ,  data analyst  ,  sql  ,  security  ,  tableau','Delhi','0 - 1','IT Software : Software Products &amp; Services','17' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong> - Looker</a> </h2>
# <h3 class="joblist-comp-name">
#     vinayak solutions pvt. limited
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Delhi">Delhi</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Company details: |. Vinsol is now a part of Snackmagic. Snackmagic is a Venture Funded New York Headquartered Technology company. At Snackmagic ,  we have an innovative take o... <a href="https://www.timesjobs.com/job-detail/data-analyst-looker-vinayak-solutions-pvt-limited-delhi-0-to-1-yrs-jobid-Qz3d8X1UiJdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           visualization  ,  <strong class="blkclor">data</strong> analysis  ,  business requirements  ,  consulting  ,  bi  ,  dashboards  ,  <strong class="blkclor">data</strong> <strong class="blkclor">analyst</strong>  ,  sql  ,  security  ,  tableau
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Delhi
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68713650">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68713650','adId=Qz3d8X1UiJdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68713650','visualization  ,  data analysis  ,  business requirements  ,  consulting  ,  bi  ,  dashboards  ,  data analyst  ,  sql  ,  security  ,  tableau','Delhi','0 - 1','IT Software : Software Products &amp; Services','17')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 1 day ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/market-data-analyst-ion-trading-india-pvt-ltd-gurgaon-0-to-1-yrs-jobid-XCKmH7qKGWlzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67623942','software development life cycle  ,  computer skills  ,  uat  ,  acceptance testing  ,  sdlc','Gurgaon','0 - 1','IT Software : Software Products &amp; Services','18' )" target="_blank">
#       Market <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     ion trading india pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Gurgaon">Gurgaon</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# As a part of the Services Team ,  analysts will be responsible for delivery of the Market Data services we offer to our Treasury SaaS clients across the globe. This position r... <a href="https://www.timesjobs.com/job-detail/market-data-analyst-ion-trading-india-pvt-ltd-gurgaon-0-to-1-yrs-jobid-XCKmH7qKGWlzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           software development life cycle  ,  computer skills  ,  uat  ,  acceptance testing  ,  sdlc
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Gurgaon
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67623942">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67623942','adId=XCKmH7qKGWlzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67623942','software development life cycle  ,  computer skills  ,  uat  ,  acceptance testing  ,  sdlc','Gurgaon','0 - 1','IT Software : Software Products &amp; Services','18')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/market-data-analyst-ion-trading-india-pvt-ltd-gurgaon-0-to-1-yrs-jobid-CvAhkeimHjhzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67623890','software development life cycle  ,  computer skills  ,  uat  ,  acceptance testing  ,  sdlc','Gurgaon','0 - 1','IT Software : Software Products &amp; Services','19' )" target="_blank">
#       Market <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     ion trading india pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Gurgaon">Gurgaon</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# This role will include coordinating with the product teams on monthly system upgrades ,  raising fix and enhancement requests in addition to performing the UAT periodically  (... <a href="https://www.timesjobs.com/job-detail/market-data-analyst-ion-trading-india-pvt-ltd-gurgaon-0-to-1-yrs-jobid-CvAhkeimHjhzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           software development life cycle  ,  computer skills  ,  uat  ,  acceptance testing  ,  sdlc
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Gurgaon
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67623890">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67623890','adId=CvAhkeimHjhzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67623890','software development life cycle  ,  computer skills  ,  uat  ,  acceptance testing  ,  sdlc','Gurgaon','0 - 1','IT Software : Software Products &amp; Services','19')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/027496.jpg" alt="AMAZON INDIA PVT LTD" title="AMAZON INDIA PVT LTD"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-support-amazon-india-pvt-ltd-bengaluru-bangalore-0-to-4-yrs-jobid-SKB7OH5VuNxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68982455','sql  ,  technical skills  ,  problem solving  ,  dash  ,  reporting tools','Bengaluru / Bangalore','0 - 4','IT Software : Software Products &amp; Services','20' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong> Support</a> </h2>
# <h3 class="joblist-comp-name">
#     AMAZON INDIA PVT LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 4 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# DESCRIPTION Job summaryAmazon Indias Supply Chain  &amp;  Analytics team is looking for technically strong Analyst for developing solutions to better manage / optimize inventory p... <a href="https://www.timesjobs.com/job-detail/data-analyst-support-amazon-india-pvt-ltd-bengaluru-bangalore-0-to-4-yrs-jobid-SKB7OH5VuNxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           sql  ,  technical skills  ,  problem solving  ,  dash  ,  reporting tools
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68982455">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68982455','adId=SKB7OH5VuNxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68982455','sql  ,  technical skills  ,  problem solving  ,  dash  ,  reporting tools','Bengaluru / Bangalore','0 - 4','IT Software : Software Products &amp; Services','20')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 5 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/045643.png" alt="Polaris Consulting & Services Ltd" title="Polaris Consulting & Services Ltd"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/eim-data-analyst-polaris-consulting-services-ltd-hyderabad-secunderabad-0-to-3-yrs-jobid-supe9bp8oTtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68922789','autosys  ,  unix scripting  ,  icm  ,  debugging  ,  technical skills  ,  oracle  ,  production support  ,  consultant','Hyderabad/Secunderabad','0 - 3','IT Software : Software Products &amp; Services','21' )" target="_blank">
#       EIM <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     Polaris Consulting &amp; Services Ltd
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Hyderabad/Secunderabad">Hyderabad/Secunderabad</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# EIM Data Analyst -  (  CREQ135490  ) DescriptionCollaborate with Product Owners and stakeholders to understand the business requirementsAnalyse data from key source systems an... <a href="https://www.timesjobs.com/job-detail/eim-data-analyst-polaris-consulting-services-ltd-hyderabad-secunderabad-0-to-3-yrs-jobid-supe9bp8oTtzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           autosys  ,  unix scripting  ,  icm  ,  debugging  ,  technical skills  ,  oracle  ,  production support  ,  consultant
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Hyderabad/Secunderabad
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68922789">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68922789','adId=supe9bp8oTtzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68922789','autosys  ,  unix scripting  ,  icm  ,  debugging  ,  technical skills  ,  oracle  ,  production support  ,  consultant','Hyderabad/Secunderabad','0 - 3','IT Software : Software Products &amp; Services','21')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 4 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/immediate-opening-for-data-analyst-applycup-hiring-solutions-llp-chennai-0-to-2-yrs-jobid-4BXKL4TQtg1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65602879','algorithms  ,  machine learning  ,  artificial intelligence  ,  data extraction  ,  written communication','Chennai','0 - 2','IT Software : Software Products &amp; Services','22' )" target="_blank">
#       Immediate opening For <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     APPLYCUP HIRING SOLUTIONS LLP
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 2 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Chennai">Chennai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Qualification : B.Tech / M.Tech / M.E  / B.E / MCA / BCA / M.Sc / B.Sc Experience : 0 - 2 YearsSkills : data analystJob Description :- Analyse large and complex data sets from... <a href="https://www.timesjobs.com/job-detail/immediate-opening-for-data-analyst-applycup-hiring-solutions-llp-chennai-0-to-2-yrs-jobid-4BXKL4TQtg1zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           algorithms  ,  machine learning  ,  artificial intelligence  ,  <strong class="blkclor">data</strong> extraction  ,  written communication
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Chennai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65602879">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65602879','adId=4BXKL4TQtg1zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65602879','algorithms  ,  machine learning  ,  artificial intelligence  ,  data extraction  ,  written communication','Chennai','0 - 2','IT Software : Software Products &amp; Services','22')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analysts-html-editor-ace-softex-pvt-ltd-rajkot-0-to-3-yrs-jobid-wlDd24X5uGpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67944038','css  ,  xml  ,  html','Rajkot','0 - 3','IT Software : Software Products &amp; Services','23' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analysts</strong> / HTML Editor</a> </h2>
# <h3 class="joblist-comp-name">
#     ace softex pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Rajkot">Rajkot</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job Description and scope of the work: Need to work in shift hours ,  first shift  ( 6:30a to 2:30p )  for female and  ( 2:30p to 10:30p )  second shift for maleWork involves ... <a href="https://www.timesjobs.com/job-detail/data-analysts-html-editor-ace-softex-pvt-ltd-rajkot-0-to-3-yrs-jobid-wlDd24X5uGpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           css  ,  xml  ,  html
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Rajkot
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67944038">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67944038','adId=wlDd24X5uGpzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67944038','css  ,  xml  ,  html','Rajkot','0 - 3','IT Software : Software Products &amp; Services','23')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/031309.png" alt="PUBLICIS GROUPE" title="PUBLICIS GROUPE"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-associate-data-analyst-publicis-groupe-ahmedabad-gurgaon-mumbai-bengaluru-bangalore-0-to-3-yrs-jobid-kZHD6__PLUS__EgdfBzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68924621','hybris  ,  sql  ,  salesforce  ,  episerver  ,  devops  ,  magento  ,  mobile  ,  demandware  ,  drupal  ,  infrastructure','Ahmedabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore','0 - 3','IT Software : Software Products &amp; Services','24' )" target="_blank">
#       Senior Associate <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     PUBLICIS GROUPE
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore">Ahmedabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Primary Skills:Very strong skills in Google Analytics 360 ,  Google Tag Manager 360 and GA4  ( GTM and GA ) Good Knowledge Firebase and Mobile Analytics TaggingData StudioExpe... <a href="https://www.timesjobs.com/job-detail/senior-associate-data-analyst-publicis-groupe-ahmedabad-gurgaon-mumbai-bengaluru-bangalore-0-to-3-yrs-jobid-kZHD6__PLUS__EgdfBzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           hybris  ,  sql  ,  salesforce  ,  episerver  ,  devops  ,  magento  ,  mobile  ,  demandware  ,  drupal  ,  infrastructure
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Ahmedabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68924621">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68924621','adId=kZHD6__PLUS__EgdfBzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68924621','hybris  ,  sql  ,  salesforce  ,  episerver  ,  devops  ,  magento  ,  mobile  ,  demandware  ,  drupal  ,  infrastructure','Ahmedabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore','0 - 3','IT Software : Software Products &amp; Services','24')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 3 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/credit-data-analyst-ion-trading-india-pvt-ltd-mumbai-0-to-3-yrs-jobid-VBBF5hJLX2JzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68687570','accounting  ,  spreadsheets  ,  legal  ,  financial accounts  ,  financial statements  ,  excel  ,  accounts','Mumbai','0 - 3','Finance','25' )" target="_blank">
#       Credit <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     ion trading india pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Mumbai">Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Over 800 of the worlds leading banks and broker-dealers use our electronic trading platforms to operate the worlds financial market infrastructure.Within ION Analytics we help... <a href="https://www.timesjobs.com/job-detail/credit-data-analyst-ion-trading-india-pvt-ltd-mumbai-0-to-3-yrs-jobid-VBBF5hJLX2JzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           accounting  ,  spreadsheets  ,  legal  ,  financial accounts  ,  financial statements  ,  excel  ,  accounts
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Mumbai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68687570">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68687570','adId=VBBF5hJLX2JzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68687570','accounting  ,  spreadsheets  ,  legal  ,  financial accounts  ,  financial statements  ,  excel  ,  accounts','Mumbai','0 - 3','Finance','25')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>]

# %%
# let us rely only on the first record using find

job = soup.find('li', class_ = 'clearfix job-bx wht-shd-bx')

# %%
print(job)
# Out:
# <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-analyst-ikomet-technology-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-uYgM1Mifhr1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68834111','macros  ,  visualization  ,  bi  ,  data analyst  ,  vba','Chennai','0 - 3','IT Software : Software Products &amp; Services','1' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     ikomet Technology Solutions Pvt. Ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Chennai">Chennai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Knowledge on R Programming ,  VBA ,  MacrosProficient in Microsoft excel with exposure on Pivot tables ,  Vlookup ,  logic formulasPresenting various analysis and reports to t... <a href="https://www.timesjobs.com/job-detail/data-analyst-ikomet-technology-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-uYgM1Mifhr1zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           macros  ,  visualization  ,  bi  ,  <strong class="blkclor">data</strong> <strong class="blkclor">analyst</strong>  ,  vba
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Chennai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_68834111">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('68834111','adId=uYgM1Mifhr1zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','68834111','macros  ,  visualization  ,  bi  ,  data analyst  ,  vba','Chennai','0 - 3','IT Software : Software Products &amp; Services','1')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>

# %%
# now we will go again into the inspect of the site to look for the tag used for company name

# %%
# by looking it, we get h3 tag is used for the company name , so we can find this tag inside our job object

# %%
company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(" ","")

# here text is used to get the text and replace is used to remove any spaces in the company name

# %%
print(company_name)
# Out:
# ikometTechnologySolutionsPvt.Ltd.

# %% [markdown]
# lets create an object for skills now

# %%
# by looking at the inspect html, we can see the tag used for skills is span and class - srp-skills
skills = job.find('span' , class_ = 'srp-skills').text.replace(" ","")

# %%
# printing the result just to check it out
print(skills)
# Out:
# macros,visualization,bi,dataanalyst,vba

# %%
# priting the result using fromated strings f''' ''', this helps to print results into the next lines as required

print(f'''
Company Name: {company_name}
Required Skills: {skills}
''')
# Out:
# Company Name:
# ikometTechnologySolutionsPvt.Ltd.
#
#
# Required Skills:
#
# macros,visualization,bi,dataanalyst,vba

# %%
# lets add one more result which will be the published_date

published_date = job.find('span', class_ = 'sim-posted').text

# %%
# priting the result using f''' ''', this helps to print results into the next lines as required

print(f'''
Company Name: {company_name}
Required Skills: {skills}
Published Date: {published_date}
''')
# Out:
# Company Name:
# ikometTechnologySolutionsPvt.Ltd.
#
#
# Required Skills:
#
# macros,visualization,bi,dataanalyst,vba
#
#
# Published Date:
# Posted few days ago

# %% [markdown]
# Let us write a code to look for all the jobs posted which are having condition that Published Date is :
# Posted few days ago

# %%
# as we used the find all command this makes a list of all the jobs

jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')

# using for loop for checking all the result
for job in jobs:
    company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(" ","")
    skills = job.find('span' , class_ = 'srp-skills').text.replace(" ","")
    published_date = job.find('span', class_ = 'sim-posted').text
    print(f'''
    Company Name: {company_name}
    Required Skills: {skills}
    Published Date: {published_date}
    ''')
# Out:
#     Company Name:
# ikometTechnologySolutionsPvt.Ltd.
#
#
#     Required Skills:
#
# macros,visualization,bi,dataanalyst,vba
#
#
#     Published Date:
# Posted few days ago
#
#
#
#     Company Name:
# ANRSOFTWAREPVTLTD
#
#
#     Required Skills:
# dataanalytics,informationmanagement,sas,spss,dataanalyst,sql,datascience,writtencommunication
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# legalwiz.inprivatelimited
#
#
#     Required Skills:
#
# informationtechnology,datamining,datawarehousing,storage,dashboards,dataanalyst,tableau,datavisualization
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# ANZGRINDLAYSBANK
#
#
#     Required Skills:
# datawarehousing,sql,database,dataanalytics,dataanalysis,oracle,businessanalysis,dataanalyst,tableau,datagovernance,analyst
#
#     Published Date:
# Posted 4 days ago
#
#
#
#     Company Name:
# iontradingindiapvt.ltd.
#
#
#     Required Skills:
#
# bi,dashboards,sql,tradingsystems,softwareengineering,datavisualization,predictiveanalysis,electronictrading,dataanalysis,consulting,dataanalyst,writtencommunication,infrastructure
#
#
#     Published Date:
# Posted few days ago
#
#
#
#     Company Name:
# BUSISOLSOURCINGINDIAPVT.LTD
#
#
#     Required Skills:
#
# charts,datamining,formulas,relationaldatabase,sqlserver,reportingservices
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# kudosindia
#
#
#     Required Skills:
#
# testcases,database,metrics,componenttesting
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# BUSISOLSOURCINGINDIAPVT.LTD
#
#
#     Required Skills:
#
# reports,charts,datamining,formulas,reportingservices,relationaldatabase,sqlserver
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# Hexanika
#
#
#     Required Skills:
#
# testdata,sqlqueries,testing,sql
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#     Required Skills:
#
# database,bi,sql
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# HyreFoxConsultants
#
#
#     Required Skills:
#
# excel,reports,reporting,monthlyreports
#
#
#     Published Date:
# Posted few days ago
#
#
#
#     Company Name:
# advancedriskanalyticsprivatelimited
#
#
#     Required Skills:
#
# visualizingdata,datacollection,Flooddata
#
#     Published Date:
# Posted few days ago
#
#
#
#     Company Name:
# AppSoftSolutions
# (MoreJobs)
#
#     Required Skills:
# DataAnalyst,SeniorDataAnalyst,DataAnalyst-TechLead,dataprofiling,datamodels,datacollection
#
#
#     Published Date:
# Posted 3 days ago
#
#
#
#     Company Name:
# RGFProfessional
#
#
#     Required Skills:
#
# teamplayer,generatehypotheses,DataAnalyst
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#     Required Skills:
#
# visualization,businessrequirements,bi,dashboards,dataanalyst,sql,tableau,security
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#     Required Skills:
# dataanalysis,msaccess,dataanalyst,sql,database,vba
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# vinayaksolutionspvt.limited
#
#
#     Required Skills:
#
# visualization,dataanalysis,businessrequirements,consulting,bi,dashboards,dataanalyst,sql,security,tableau
#
#
#     Published Date:
# Posted 1 day ago
#
#
#
#     Company Name:
# iontradingindiapvt.ltd.
#
#
#     Required Skills:
#
# softwaredevelopmentlifecycle,computerskills,uat,acceptancetesting,sdlc
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# iontradingindiapvt.ltd.
#
#
#     Required Skills:
#
# softwaredevelopmentlifecycle,computerskills,uat,acceptancetesting,sdlc
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# AMAZONINDIAPVTLTD
#
#
#     Required Skills:
#
# sql,technicalskills,problemsolving,dash,reportingtools
#
#
#     Published Date:
# Posted 5 days ago
#
#
#
#     Company Name:
# PolarisConsulting&ServicesLtd
#
#
#     Required Skills:
#
# autosys,unixscripting,icm,debugging,technicalskills,oracle,productionsupport,consultant
#
#
#     Published Date:
# Posted 4 days ago
#
#
#
#     Company Name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#     Required Skills:
#
# algorithms,machinelearning,artificialintelligence,dataextraction,writtencommunication
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# acesoftexpvt.ltd.
#
#
#     Required Skills:
#
# css,xml,html
#
#
#     Published Date:
# Posted 2 days ago
#
#
#
#     Company Name:
# PUBLICISGROUPE
#
#
#     Required Skills:
#
# hybris,sql,salesforce,episerver,devops,magento,mobile,demandware,drupal,infrastructure
#
#
#     Published Date:
# Posted 3 days ago
#
#
#
#     Company Name:
# iontradingindiapvt.ltd.
#
#
#     Required Skills:
#
# accounting,spreadsheets,legal,financialaccounts,financialstatements,excel,accounts
#
#
#     Published Date:
# Posted few days ago

# %%
# now writing an if statement to make sure the publishing is matching the condition

jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
i = 1 #(Using this for count purpose in the result)
# using for loop for checking all the result
for job in jobs:
    published_date = job.find('span', class_ = 'sim-posted').text
    
# we are checking if the word 'few' is inside the published_date
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(" ","")
        skills = job.find('span' , class_ = 'srp-skills').text.replace(" ","")
        print(i)
        print(f'''
        Company Name: {company_name}
        Required Skills: {skills}
        Published Date: {published_date}
        ''')
        i = i + 1
# Out:
# 1
#
#         Company Name:
# ikometTechnologySolutionsPvt.Ltd.
#
#
#         Required Skills:
#
# macros,visualization,bi,dataanalyst,vba
#
#
#         Published Date:
# Posted few days ago
#
#
# 2
#
#         Company Name:
# iontradingindiapvt.ltd.
#
#
#         Required Skills:
#
# bi,dashboards,sql,tradingsystems,softwareengineering,datavisualization,predictiveanalysis,electronictrading,dataanalysis,consulting,dataanalyst,writtencommunication,infrastructure
#
#
#         Published Date:
# Posted few days ago
#
#
# 3
#
#         Company Name:
# HyreFoxConsultants
#
#
#         Required Skills:
#
# excel,reports,reporting,monthlyreports
#
#
#         Published Date:
# Posted few days ago
#
#
# 4
#
#         Company Name:
# advancedriskanalyticsprivatelimited
#
#
#         Required Skills:
#
# visualizingdata,datacollection,Flooddata
#
#         Published Date:
# Posted few days ago
#
#
# 5
#
#         Company Name:
# iontradingindiapvt.ltd.
#
#
#         Required Skills:
#
# accounting,spreadsheets,legal,financialaccounts,financialstatements,excel,accounts
#
#
#         Published Date:
# Posted few days ago

# %%
# there is alignment problem so we will first fix the alignment part for it
# copy pastying the same code

# %%
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
i = 1 #(Using this for count purpose in the result)
# using for loop for checking all the result
for job in jobs:
    published_date = job.find('span', class_ = 'sim-posted').text
    
# we are checking if the word 'few' is inside the published_date
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(" ","")
        skills = job.find('span' , class_ = 'srp-skills').text.replace(" ","")
        print(i)
        print(f'Company Name: {company_name}')
        print(f'Required Skills: {skills}')
        print(f'Published Date: {published_date}')
        i = i + 1
# Out:
# 1
# Company Name:
# ikometTechnologySolutionsPvt.Ltd.
#
#
# Required Skills:
#
# macros,visualization,bi,dataanalyst,vba
#
#
# Published Date:
# Posted few days ago
#
# 2
# Company Name:
# iontradingindiapvt.ltd.
#
#
# Required Skills:
#
# bi,dashboards,sql,tradingsystems,softwareengineering,datavisualization,predictiveanalysis,electronictrading,dataanalysis,consulting,dataanalyst,writtencommunication,infrastructure
#
#
# Published Date:
# Posted few days ago
#
# 3
# Company Name:
# HyreFoxConsultants
#
#
# Required Skills:
#
# excel,reports,reporting,monthlyreports
#
#
# Published Date:
# Posted few days ago
#
# 4
# Company Name:
# advancedriskanalyticsprivatelimited
#
#
# Required Skills:
#
# visualizingdata,datacollection,Flooddata
#
# Published Date:
# Posted few days ago
#
# 5
# Company Name:
# iontradingindiapvt.ltd.
#
#
# Required Skills:
#
# accounting,spreadsheets,legal,financialaccounts,financialstatements,excel,accounts
#
#
# Published Date:
# Posted few days ago

# %%
# now let us also get the link of the job description to know more about a particular job

# %%
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
i = 1 #(Using this for count purpose in the result)
# using for loop for checking all the result
for job in jobs:
    published_date = job.find('span', class_ = 'sim-posted').text
    
# we are checking if the word 'few' is inside the published_date
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(" ","")
        skills = job.find('span' , class_ = 'srp-skills').text.replace(" ","")
        #header is used in more info as the first tag
        # a is the tag for the link 
        more_info = job.header.h2.a
        print(i)
        print(f'Company Name: {company_name}')
        print(f'Required Skills: {skills}')
        print(f'Published Date: {published_date}')
        print(f'More info: {more_info}')
        i = i + 1
# Out:
# 1
# Company Name:
# ikometTechnologySolutionsPvt.Ltd.
#
#
# Required Skills:
#
# macros,visualization,bi,dataanalyst,vba
#
#
# Published Date:
# Posted few days ago
#
# More info: <a href="https://www.timesjobs.com/job-detail/data-analyst-ikomet-technology-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-uYgM1Mifhr1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68834111','macros  ,  visualization  ,  bi  ,  data analyst  ,  vba','Chennai','0 - 3','IT Software : Software Products &amp; Services','1' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a>
# 2
# Company Name:
# iontradingindiapvt.ltd.
#
#
# Required Skills:
#
# bi,dashboards,sql,tradingsystems,softwareengineering,datavisualization,predictiveanalysis,electronictrading,dataanalysis,consulting,dataanalyst,writtencommunication,infrastructure
#
#
# Published Date:
# Posted few days ago
#
# More info: <a href="https://www.timesjobs.com/job-detail/data-analyst-ion-trading-india-pvt-ltd-noida-greater-noida-0-to-3-yrs-jobid-QDeB2K4ih45zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68716403','bi  ,  dashboards  ,  sql  ,  trading systems  ,  software engineering  ,  data visualization  ,  predictive analysis  ,  electronic trading  ,  data analysis  ,  consulting  ,  data analyst  ,  written communication  ,  infrastructure','Noida/Greater Noida','0 - 3','IT Software : Software Products &amp; Services','5' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a>
# 3
# Company Name:
# HyreFoxConsultants
#
#
# Required Skills:
#
# excel,reports,reporting,monthlyreports
#
#
# Published Date:
# Posted few days ago
#
# More info: <a href="https://www.timesjobs.com/job-detail/data-analyst-hyrefox-consultants-jaipur-0-to-3-yrs-jobid-KwT1r6nTXxFzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68952744','excel  ,  reports  ,  reporting  ,  monthly reports','Jaipur','0 - 3','Accounting  /  Tax  /  Company Secretary  /  Audit','11' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a>
# 4
# Company Name:
# advancedriskanalyticsprivatelimited
#
#
# Required Skills:
#
# visualizingdata,datacollection,Flooddata
#
# Published Date:
# Posted few days ago
#
# More info: <a href="https://www.timesjobs.com/job-detail/data-analyst-advanced-risk-analytics-private-limited-pune-0-to-3-yrs-jobid-TmPblskT8fVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65511980','visualizing data  ,  data collection  ,  Flood data','Pune','0 - 3','IT Software : Software Products &amp; Services','12' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a>
# 5
# Company Name:
# iontradingindiapvt.ltd.
#
#
# Required Skills:
#
# accounting,spreadsheets,legal,financialaccounts,financialstatements,excel,accounts
#
#
# Published Date:
# Posted few days ago
#
# More info: <a href="https://www.timesjobs.com/job-detail/credit-data-analyst-ion-trading-india-pvt-ltd-mumbai-0-to-3-yrs-jobid-VBBF5hJLX2JzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','68687570','accounting  ,  spreadsheets  ,  legal  ,  financial accounts  ,  financial statements  ,  excel  ,  accounts','Mumbai','0 - 3','Finance','25' )" target="_blank">
#       Credit <strong class="blkclor">Data</strong> <strong class="blkclor">Analyst</strong></a>

# %%
# but we just need the link to the description so we will use href as the key of the dictionary into it

# %%
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
i = 1 #(Using this for count purpose in the result)
# using for loop for checking all the result
for job in jobs:
    published_date = job.find('span', class_ = 'sim-posted').text
    
# we are checking if the word 'few' is inside the published_date
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(" ","")
        skills = job.find('span' , class_ = 'srp-skills').text.replace(" ","")
        #header is used in more info as the first tag because the link lies in the heading h2
        # a is the tag for the link and index we have is 'href'
        more_info = job.header.h2.a['href']
        print(i)
        print(" ")
        print(f'Company Name: {company_name}')
        print(f'Required Skills: {skills}')
        print(f'Published Date: {published_date}')
        print(f'More info: {more_info}')
        # printing some space at the end
        print(" ")
        i = i + 1
# Out:
# 1
#
# Company Name:
# ikometTechnologySolutionsPvt.Ltd.
#
#
# Required Skills:
#
# macros,visualization,bi,dataanalyst,vba
#
#
# Published Date:
# Posted few days ago
#
# More info: https://www.timesjobs.com/job-detail/data-analyst-ikomet-technology-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-uYgM1Mifhr1zpSvf__PLUS__uAgZw==&source=srp
#
# 2
#
# Company Name:
# iontradingindiapvt.ltd.
#
#
# Required Skills:
#
# bi,dashboards,sql,tradingsystems,softwareengineering,datavisualization,predictiveanalysis,electronictrading,dataanalysis,consulting,dataanalyst,writtencommunication,infrastructure
#
#
# Published Date:
# Posted few days ago
#
# More info: https://www.timesjobs.com/job-detail/data-analyst-ion-trading-india-pvt-ltd-noida-greater-noida-0-to-3-yrs-jobid-QDeB2K4ih45zpSvf__PLUS__uAgZw==&source=srp
#
# 3
#
# Company Name:
# HyreFoxConsultants
#
#
# Required Skills:
#
# excel,reports,reporting,monthlyreports
#
#
# Published Date:
# Posted few days ago
#
# More info: https://www.timesjobs.com/job-detail/data-analyst-hyrefox-consultants-jaipur-0-to-3-yrs-jobid-KwT1r6nTXxFzpSvf__PLUS__uAgZw==&source=srp
#
# 4
#
# Company Name:
# advancedriskanalyticsprivatelimited
#
#
# Required Skills:
#
# visualizingdata,datacollection,Flooddata
#
# Published Date:
# Posted few days ago
#
# More info: https://www.timesjobs.com/job-detail/data-analyst-advanced-risk-analytics-private-limited-pune-0-to-3-yrs-jobid-TmPblskT8fVzpSvf__PLUS__uAgZw==&source=srp
#
# 5
#
# Company Name:
# iontradingindiapvt.ltd.
#
#
# Required Skills:
#
# accounting,spreadsheets,legal,financialaccounts,financialstatements,excel,accounts
#
#
# Published Date:
# Posted few days ago
#
# More info: https://www.timesjobs.com/job-detail/credit-data-analyst-ion-trading-india-pvt-ltd-mumbai-0-to-3-yrs-jobid-VBBF5hJLX2JzpSvf__PLUS__uAgZw==&source=srp

# %%
# next we can filter out the result as per the skillset of the applicant: using another if conditon for it

# %%
# these skills will be something which we will take as a input from the user

# %%
print('Put some skills that you are familiar with')
familiar_skill = input('>')
# Out:
# Put some skills that you are familiar with
# >data

# %%
print(f'Filtering out jobs based on your skills : {familiar_skill}')
# Out:
# Filtering out jobs based on your skills : data

# %%
# let us put a if condition to filter out the skill set as well

jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
i = 1 #(Using this for count purpose in the result)
# using for loop for checking all the result
for job in jobs:
    published_date = job.find('span', class_ = 'sim-posted').text
    
# we are checking if the word 'few' is inside the published_date
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(" ","")
        skills = job.find('span' , class_ = 'srp-skills').text.replace(" ","")
        if familiar_skill in skills:
            #header is used in more info as the first tag because the link lies in the heading h2
            # a is the tag for the link and index we have is 'href'
            more_info = job.header.h2.a['href']
            print(i)
            print(" ")
            print(f'Company Name: {company_name}')
            print(f'Required Skills: {skills}')
            print(f'Published Date: {published_date}')
            print(f'More info: {more_info}')
            # printing some space at the end
            print(" ")
            i = i + 1
# Out:
# 1
#
# Company Name:
# ikometTechnologySolutionsPvt.Ltd.
#
#
# Required Skills:
#
# macros,visualization,bi,dataanalyst,vba
#
#
# Published Date:
# Posted few days ago
#
# More info: https://www.timesjobs.com/job-detail/data-analyst-ikomet-technology-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-uYgM1Mifhr1zpSvf__PLUS__uAgZw==&source=srp
#
# 2
#
# Company Name:
# iontradingindiapvt.ltd.
#
#
# Required Skills:
#
# bi,dashboards,sql,tradingsystems,softwareengineering,datavisualization,predictiveanalysis,electronictrading,dataanalysis,consulting,dataanalyst,writtencommunication,infrastructure
#
#
# Published Date:
# Posted few days ago
#
# More info: https://www.timesjobs.com/job-detail/data-analyst-ion-trading-india-pvt-ltd-noida-greater-noida-0-to-3-yrs-jobid-QDeB2K4ih45zpSvf__PLUS__uAgZw==&source=srp
#
# 3
#
# Company Name:
# advancedriskanalyticsprivatelimited
#
#
# Required Skills:
#
# visualizingdata,datacollection,Flooddata
#
# Published Date:
# Posted few days ago
#
# More info: https://www.timesjobs.com/job-detail/data-analyst-advanced-risk-analytics-private-limited-pune-0-to-3-yrs-jobid-TmPblskT8fVzpSvf__PLUS__uAgZw==&source=srp

# %%
#Let us create a function for the execution of these codes
def find_jobs():
    jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
    i = 1 #(Using this for count purpose in the result)
    # using for loop for checking all the result
    for job in jobs:
        published_date = job.find('span', class_ = 'sim-posted').text

    # we are checking if the word 'few' is inside the published_date
        if 'few' in published_date:
            company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(" ","")
            skills = job.find('span' , class_ = 'srp-skills').text.replace(" ","")
            if familiar_skill in skills:
                #header is used in more info as the first tag because the link lies in the heading h2
                # a is the tag for the link and index we have is 'href'
                more_info = job.header.h2.a['href']
                print(i)
                print(" ")
                print(f'Company Name: {company_name}')
                print(f'Required Skills: {skills}')
                print(f'Published Date: {published_date}')
                print(f'More info: {more_info}')
                # printing some space at the end
                print(" ")
                i = i + 1

# %%
# to automate the execution of code as per need

import time
if __name__ == '__main__':
    while True:
        find_jobs()
        time_wait = 10
        print(f'Waiting time {time_wait} minutes...')
        time.sleep(time_wait*60)

# %%
# this will make this program to run after every 10 minutes

# %%
# getting the results into a text file

def find_jobs():
    html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Data+Analyst&txtLocation=India&cboWorkExp1=0').text
    soup = BeautifulSoup(html_text, 'lxml')
    jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
    i = 1 #(Using this for count purpose in the result)
    # using for loop for checking all the result
    for index, job in enumerate(jobs):
        published_date = job.find('span', class_ = 'sim-posted').text

    # we are checking if the word 'few' is inside the published_date
        if 'few' in published_date:
            company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(" ","")
            skills = job.find('span' , class_ = 'srp-skills').text.replace(" ","")
            if familiar_skill in skills:
                with open(f'posts/{index}.txt', 'w') as f:
                    #header is used in more info as the first tag because the link lies in the heading h2
                    # a is the tag for the link and index we have is 'href'
                    more_info = job.header.h2.a['href']
                    f.write(i)
                    f.write(" ")
                    f.write(f'Company Name: {company_name} \n')
                    f.write(f'Required Skills: {skills} \n')
                    f.write(f'Published Date: {published_date} \n')
                    f.write(f'More info: {more_info} \n')
                    # printing some space at the end
                    f.write(" ")
                    i = i + 1
                 print(f'file saved: {index}')   

                
# to automate the execution of code as per need

import time
if __name__ == '__main__':
    while True:
        find_jobs()
        time_wait = 10
        print(f'Waiting time {time_wait} minutes...')
        time.sleep(time_wait*60)
